-- %% [markdown]
-- # [AliExpressDB]

-- %%
USE [master]
GO

-- %%
/****** Object:  Database [AliExpressDB]    Script Date: 13.04.2024 10:05:39 ******/
CREATE DATABASE [AliExpressDB]
 CONTAINMENT = NONE
 ON  PRIMARY 
( NAME = N'AliExpressDB', FILENAME = N'C:\Users\Admin\Desktop\MSSQL16.MSSQLSERVER\MSSQL\DATA\AliExpressDB.mdf' , SIZE = 8192KB , MAXSIZE = UNLIMITED, FILEGROWTH = 65536KB )
 LOG ON 
( NAME = N'AliExpressDB_log', FILENAME = N'C:\Users\Admin\Desktop\MSSQL16.MSSQLSERVER\MSSQL\DATA\AliExpressDB_log.ldf' , SIZE = 8192KB , MAXSIZE = 2048GB , FILEGROWTH = 65536KB )
 WITH CATALOG_COLLATION = DATABASE_DEFAULT, LEDGER = OFF
GO
ALTER DATABASE [AliExpressDB] SET COMPATIBILITY_LEVEL = 160
GO
IF (1 = FULLTEXTSERVICEPROPERTY('IsFullTextInstalled'))
begin
EXEC [AliExpressDB].[dbo].[sp_fulltext_database] @action = 'enable'
end
GO
ALTER DATABASE [AliExpressDB] SET ANSI_NULL_DEFAULT OFF 
GO
ALTER DATABASE [AliExpressDB] SET ANSI_NULLS OFF 
GO
ALTER DATABASE [AliExpressDB] SET ANSI_PADDING OFF 
GO
ALTER DATABASE [AliExpressDB] SET ANSI_WARNINGS OFF 
GO
ALTER DATABASE [AliExpressDB] SET ARITHABORT OFF 
GO
ALTER DATABASE [AliExpressDB] SET AUTO_CLOSE OFF 
GO
ALTER DATABASE [AliExpressDB] SET AUTO_SHRINK OFF 
GO
ALTER DATABASE [AliExpressDB] SET AUTO_UPDATE_STATISTICS ON 
GO
ALTER DATABASE [AliExpressDB] SET CURSOR_CLOSE_ON_COMMIT OFF 
GO
ALTER DATABASE [AliExpressDB] SET CURSOR_DEFAULT  GLOBAL 
GO
ALTER DATABASE [AliExpressDB] SET CONCAT_NULL_YIELDS_NULL OFF 
GO
ALTER DATABASE [AliExpressDB] SET NUMERIC_ROUNDABORT OFF 
GO
ALTER DATABASE [AliExpressDB] SET QUOTED_IDENTIFIER OFF 
GO
ALTER DATABASE [AliExpressDB] SET RECURSIVE_TRIGGERS OFF 
GO
ALTER DATABASE [AliExpressDB] SET  ENABLE_BROKER 
GO
ALTER DATABASE [AliExpressDB] SET AUTO_UPDATE_STATISTICS_ASYNC OFF 
GO
ALTER DATABASE [AliExpressDB] SET DATE_CORRELATION_OPTIMIZATION OFF 
GO
ALTER DATABASE [AliExpressDB] SET TRUSTWORTHY OFF 
GO
ALTER DATABASE [AliExpressDB] SET ALLOW_SNAPSHOT_ISOLATION OFF 
GO
ALTER DATABASE [AliExpressDB] SET PARAMETERIZATION SIMPLE 
GO
ALTER DATABASE [AliExpressDB] SET READ_COMMITTED_SNAPSHOT OFF 
GO
ALTER DATABASE [AliExpressDB] SET HONOR_BROKER_PRIORITY OFF 
GO
ALTER DATABASE [AliExpressDB] SET RECOVERY FULL 
GO
ALTER DATABASE [AliExpressDB] SET  MULTI_USER 
GO
ALTER DATABASE [AliExpressDB] SET PAGE_VERIFY CHECKSUM  
GO
ALTER DATABASE [AliExpressDB] SET DB_CHAINING OFF 
GO
ALTER DATABASE [AliExpressDB] SET FILESTREAM( NON_TRANSACTED_ACCESS = OFF ) 
GO
ALTER DATABASE [AliExpressDB] SET TARGET_RECOVERY_TIME = 60 SECONDS 
GO
ALTER DATABASE [AliExpressDB] SET DELAYED_DURABILITY = DISABLED 
GO
ALTER DATABASE [AliExpressDB] SET ACCELERATED_DATABASE_RECOVERY = OFF  
GO
EXEC sys.sp_db_vardecimal_storage_format N'AliExpressDB', N'ON'
GO
ALTER DATABASE [AliExpressDB] SET QUERY_STORE = ON
GO
ALTER DATABASE [AliExpressDB] SET QUERY_STORE (OPERATION_MODE = READ_WRITE, CLEANUP_POLICY = (STALE_QUERY_THRESHOLD_DAYS = 30), DATA_FLUSH_INTERVAL_SECONDS = 900, INTERVAL_LENGTH_MINUTES = 60, MAX_STORAGE_SIZE_MB = 1000, QUERY_CAPTURE_MODE = AUTO, SIZE_BASED_CLEANUP_MODE = AUTO, MAX_PLANS_PER_QUERY = 200, WAIT_STATS_CAPTURE_MODE = ON)
GO

-- %% [markdown]
-- # [dbo].[Categories]

-- %%
USE [AliExpressDB]
GO

-- %%
/****** Object:  Table [dbo].[Categories]    Script Date: 13.04.2024 10:05:39 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Categories](
	[CategoryId] [int] IDENTITY(1,1) NOT NULL,
	[CategoryName] [nvarchar](255) NOT NULL,
	[Description] [text] NOT NULL,
 CONSTRAINT [PK_Categories] PRIMARY KEY CLUSTERED 
(
	[CategoryId] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Costumerdemographics]

-- %%
/****** Object:  Table [dbo].[Costumerdemographics]    Script Date: 13.04.2024 10:05:39 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Costumerdemographics](
	[CustomerId] [nvarchar](255) NOT NULL,
	[CustomerTypeId] [nvarchar](255) NOT NULL,
 CONSTRAINT [PK_Costumerdemographics] PRIMARY KEY CLUSTERED 
(
	[CustomerId] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Costumers]

-- %%
/****** Object:  Table [dbo].[Costumers]    Script Date: 13.04.2024 10:05:39 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Costumers](
	[CostomerId] [nvarchar](255) NOT NULL,
	[CompanyName] [nvarchar](255) NOT NULL,
	[ContactName] [nvarchar](255) NOT NULL,
	[ContactTitle] [nvarchar](255) NOT NULL,
	[Address] [nvarchar](255) NOT NULL,
	[City] [nvarchar](255) NOT NULL,
	[Region] [nvarchar](255) NOT NULL,
	[PostalCode] [nvarchar](255) NOT NULL,
	[Country] [nvarchar](255) NOT NULL,
	[Phone] [nvarchar](255) NOT NULL,
	[Fax] [nvarchar](255) NOT NULL,
 CONSTRAINT [PK_Costumers] PRIMARY KEY CLUSTERED 
(
	[CostomerId] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Employees]

-- %%
/****** Object:  Table [dbo].[Employees]    Script Date: 13.04.2024 10:05:39 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Employees](
	[EmployeeId] [int] IDENTITY(1,1) NOT NULL,
	[Name] [nvarchar](255) NOT NULL,
	[Surname] [nvarchar](255) NOT NULL,
	[BirthDate] [date] NOT NULL,
	[Address] [nvarchar](255) NOT NULL,
	[City] [nvarchar](255) NOT NULL,
	[Region] [nvarchar](255) NOT NULL,
	[HomePhone] [nvarchar](255) NOT NULL,
	[Salary] [float] NOT NULL,
 CONSTRAINT [PK_Employees] PRIMARY KEY CLUSTERED 
(
	[EmployeeId] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[EmployeeTerritories]

-- %%
/****** Object:  Table [dbo].[EmployeeTerritories]    Script Date: 13.04.2024 10:05:39 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[EmployeeTerritories](
	[EmployeeId] [int] IDENTITY(1,1) NOT NULL,
	[Territory] [nvarchar](255) NOT NULL,
 CONSTRAINT [PK_EmployeeTerritories] PRIMARY KEY CLUSTERED 
(
	[EmployeeId] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Orderdetalis]

-- %%
/****** Object:  Table [dbo].[Orderdetalis]    Script Date: 13.04.2024 10:05:39 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Orderdetalis](
	[OrderId] [int] IDENTITY(1,1) NOT NULL,
	[ProductId] [int] NOT NULL,
	[UnitPrice] [decimal](18, 0) NOT NULL,
	[Quanity] [int] NOT NULL,
 CONSTRAINT [PK_Orderdetalis] PRIMARY KEY CLUSTERED 
(
	[OrderId] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Orders]

-- %%
/****** Object:  Table [dbo].[Orders]    Script Date: 13.04.2024 10:05:39 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Orders](
	[OrderId] [int] IDENTITY(1,1) NOT NULL,
	[CostumerId] [nvarchar](255) NOT NULL,
	[EployeeId] [int] NOT NULL,
	[OrderDate] [date] NOT NULL,
	[ShipName] [nvarchar](255) NOT NULL,
	[ShipAddress] [nvarchar](255) NOT NULL,
 CONSTRAINT [PK_Orders] PRIMARY KEY CLUSTERED 
(
	[OrderId] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Products]

-- %%
/****** Object:  Table [dbo].[Products]    Script Date: 13.04.2024 10:05:39 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Products](
	[ProductId] [int] IDENTITY(1,1) NOT NULL,
	[ProductName] [nvarchar](255) NOT NULL,
	[SupplierId] [int] NOT NULL,
	[CategoryId] [int] NOT NULL,
	[QuantityPerUnit] [nvarchar](255) NOT NULL,
	[UnitPrice] [decimal](18, 0) NOT NULL,
	[UnitsInStock] [smallint] NOT NULL,
	[UnitOnOrder] [smallint] NOT NULL,
	[ReorderLevel] [smallint] NOT NULL,
 CONSTRAINT [PK_Products] PRIMARY KEY CLUSTERED 
(
	[ProductId] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Region]

-- %%
/****** Object:  Table [dbo].[Region]    Script Date: 13.04.2024 10:05:39 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Region](
	[RegionId] [int] IDENTITY(1,1) NOT NULL,
	[RegionDecription] [nvarchar](255) NOT NULL,
 CONSTRAINT [PK_Region] PRIMARY KEY CLUSTERED 
(
	[RegionId] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Shippers]

-- %%
/****** Object:  Table [dbo].[Shippers]    Script Date: 13.04.2024 10:05:39 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Shippers](
	[Shippersİd] [int] NULL,
	[CompanyName] [nvarchar](255) NULL,
	[Phone] [nvarchar](255) NULL
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Suppliers]

-- %%
/****** Object:  Table [dbo].[Suppliers]    Script Date: 13.04.2024 10:05:39 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Suppliers](
	[SupplierId] [int] IDENTITY(1,1) NOT NULL,
	[CompanyName] [nvarchar](255) NOT NULL,
	[ContactName] [nvarchar](255) NOT NULL,
	[ContactTitle] [nvarchar](255) NOT NULL,
	[Adress] [nvarchar](255) NOT NULL,
	[City] [nvarchar](255) NOT NULL,
	[Region] [nvarchar](255) NOT NULL,
	[PostalCode] [nvarchar](255) NOT NULL,
	[Country] [nvarchar](255) NOT NULL,
	[Phone] [nvarchar](255) NOT NULL,
	[Fax] [nvarchar](255) NOT NULL,
	[HomePage] [text] NOT NULL,
 CONSTRAINT [PK_Suppliers] PRIMARY KEY CLUSTERED 
(
	[SupplierId] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Territories]

-- %%
/****** Object:  Table [dbo].[Territories]    Script Date: 13.04.2024 10:05:39 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Territories](
	[TerritoryId] [nvarchar](255) NOT NULL,
	[TerritoryDescription] [nvarchar](255) NOT NULL,
	[RegionId] [int] NOT NULL,
 CONSTRAINT [PK_Territories] PRIMARY KEY CLUSTERED 
(
	[TerritoryId] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [AliExpressDB]

-- %%
USE [master]
GO

-- %%
ALTER DATABASE [AliExpressDB] SET  READ_WRITE 
GO
